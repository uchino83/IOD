# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# get matplot to show charts inline
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# chrome://settings/content/cookies
#
# NOTE: Make sure third party cookies are not blocked.

# %%
df = pd.read_csv('/Users/uchino/Desktop/IoD/Employee-attrition.csv')

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.tail()
# Out:
#        EmployeeID  recorddate_key birthdate_key orighiredate_key  \
# 49648        8258  12/1/2015 0:00     5/28/1994        8/19/2013
# 49649        8264   8/1/2013 0:00     6/13/1994        8/27/2013
# 49650        8279  12/1/2015 0:00     7/18/1994        9/15/2013
# 49651        8296  12/1/2013 0:00      9/2/1994        10/9/2013
# 49652        8321  12/1/2014 0:00    11/28/1994       11/24/2013
#
#       terminationdate_key  age  length_of_service    city_name  \
# 49648          12/30/2015   21                  2    Valemount
# 49649           8/30/2013   19                  0    Vancouver
# 49650          12/30/2015   21                  2   White Rock
# 49651          12/31/2013   19                  0      Kelowna
# 49652          12/30/2014   20                  1  Grand Forks
#
#         department_name     job_title  store_name gender_short gender_full  \
# 49648             Dairy  Dairy Person          34            M        Male
# ...

# %% [markdown]
# # Accessing the main DataFrame components

# %%
columns = df.columns
index = df.index
data = df.values

# %%
columns
# Out:
# Index(['EmployeeID', 'recorddate_key', 'birthdate_key', 'orighiredate_key',
#        'terminationdate_key', 'age', 'length_of_service', 'city_name',
#        'department_name', 'job_title', 'store_name', 'gender_short',
#        'gender_full', 'termreason_desc', 'termtype_desc', 'STATUS_YEAR',
#        'STATUS', 'BUSINESS_UNIT'],
#       dtype='object')

# %%
index
# Out:
# RangeIndex(start=0, stop=49653, step=1)

# %%
data
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %% [markdown]
# # 1. Understanding Data Types

# %% [markdown]
# #### 1.A Find Shape of Data Frame

# %%
# A:
df.shape
# Out:
# (49653, 18)

# %% [markdown]
# #### 1.B Find Data Tyeps of Data Frame

# %%
# A:
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %% [markdown]
# #### 1.C Find Number of Data Types in a Data Frame
#
#
#
# ```
# Expected Output:
# int64      5
# object    13
# dtype: int64
# ```

# %% [markdown]
# #### 1.D Use Info
#
# Use info and explore difference.

# %%
# A:
df.info
# Out:
# <bound method DataFrame.info of        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5            1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6            1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7            1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8            1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9            1318  12/31/2015 0:00      1/3/1954        8/28/1989
# 10           1319  12/31/2006 0:00      1/3/1957        8/28/1989
# 11           1319  12/31/2007 0:00      1/3/1957        8/28/1989
# 12           1319  12/31/2008 0:00      1/3/1957        8/28/1989
# ...

# %% [markdown]
# # 2. Selecting Column in Data Frame

# %% [markdown]
# #### 2.A Check Values of Job_Title column

# %%
# A:
df['job_title']
# Out:
# 0                  CEO
# 1                  CEO
# 2                  CEO
# 3                  CEO
# 4                  CEO
# 5                  CEO
# 6                  CEO
# 7                  CEO
# 8                  CEO
# 9                  CEO
# 10           VP Stores
# 11           VP Stores
# 12           VP Stores
# 13           VP Stores
# 14           VP Stores
# 15           VP Stores
# 16           VP Stores
# 17           VP Stores
# 18           VP Stores
# 19           VP Stores
# 20       Legal Counsel
# 21       Legal Counsel
# 22       Legal Counsel
# 23       Legal Counsel
# 24       Legal Counsel
# 25       Legal Counsel
# 26       Legal Counsel
# 27       Legal Counsel
# 28       Legal Counsel
# 29       Legal Counsel
#              ...
# 49623          Cashier
# 49624          Cashier
# 49625          Cashier
# 49626          Cashier
# 49627          Cashier
# 49628          Cashier
# 49629          Cashier
# 49630          Cashier
# 49631          Cashier
# ...

# %% [markdown]
# #### 2.B Find How Many Rows Are in Each Job Title
#
#
#
# ```
# # Expected Output
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# .
# .
# .
# ```

# %%
# A:
df['job_title'].value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Meats Manager                       285
# Bakery Manager                      285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Investment Analyst                   20
# Systems Analyst                      20
# ...

# %% [markdown]
# #### 2.C [BONUS] Write A Function to Row Count
#
#
#
# ```
# def row_count(column_name):
#     number_of_rows = 0
#     return number_of_rows
# ```

# %% [markdown]
# #### 2.D Describe 'Age'
#
# Find count,  mean,  std, min, max of column 'age'

# %%
# A:
df.groupby('EmployeeID').agg({'age': ['count','std','mean', 'min', 'max']})
# Out:
#              age
#            count       std  mean min max
# EmployeeID
# 1318          10  3.027650  56.5  52  61
# 1319          10  3.027650  53.5  49  58
# 1320          10  3.027650  55.5  51  60
# 1321          10  3.027650  51.5  47  56
# 1322          10  3.027650  52.5  48  57
# 1323          10  3.027650  48.5  44  53
# 1325          10  3.027650  46.5  42  51
# 1328          10  3.027650  54.5  50  59
# 1329          10  3.027650  43.5  39  48
# 1330          10  3.027650  43.5  39  48
# 1331          10  3.027650  45.5  41  50
# 1332          10  3.027650  55.5  51  60
# 1334          10  3.027650  49.5  45  54
# 1335          10  3.027650  48.5  44  53
# 1338           4  1.290994  58.5  57  60
# 1339           9  2.738613  61.0  57  65
# 1340           4  1.290994  58.5  57  60
# 1341           4  1.290994  58.5  57  60
# 1343           9  2.738613  61.0  57  65
# 1344           9  2.738613  61.0  57  65
# 1346           9  2.738613  61.0  57  65
# ...

# %% [markdown]
# ##### 2.E [BONUS] Describe 'All Numeric Columns of Data Frame
#
# Find count, mean, std, min, max of of all columns of dataframe

# %%
# A:
df.describe()
# Out:
#          EmployeeID           age  length_of_service    store_name  \
# count  49653.000000  49653.000000       49653.000000  49653.000000
# mean    4859.495740     42.077035          10.434596     27.297605
# std     1826.571142     12.427257           6.325286     13.514134
# min     1318.000000     19.000000           0.000000      1.000000
# 25%     3360.000000     31.000000           5.000000     16.000000
# 50%     5031.000000     42.000000          10.000000     28.000000
# 75%     6335.000000     53.000000          15.000000     42.000000
# max     8336.000000     65.000000          26.000000     46.000000
#
#         STATUS_YEAR
# count  49653.000000
# mean    2010.612612
# std        2.845577
# min     2006.000000
# 25%     2008.000000
# 50%     2011.000000
# 75%     2013.000000
# max     2015.000000

# %% [markdown]
# # 3. Making The Index Meaningful

# %%
# A:

# %% [markdown]
# #### 3.A Find A Specifc Row Using Index

# %%
# A:
df.iloc[3]
# Out:
# EmployeeID                        1318
# recorddate_key         12/31/2009 0:00
# birthdate_key                 1/3/1954
# orighiredate_key             8/28/1989
# terminationdate_key           1/1/1900
# age                                 55
# length_of_service                   20
# city_name                    Vancouver
# department_name              Executive
# job_title                          CEO
# store_name                          35
# gender_short                         M
# gender_full                       Male
# termreason_desc         Not Applicable
# termtype_desc           Not Applicable
# STATUS_YEAR                       2009
# STATUS                          ACTIVE
# BUSINESS_UNIT               HEADOFFICE
# Name: 3, dtype: object

# %% [markdown]
# #### 3.B Sort Data Frame using Index

# %%
# A:
df.sort_index()
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0            1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1            1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2            1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3            1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4            1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5            1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6            1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7            1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8            1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9            1318  12/31/2015 0:00      1/3/1954        8/28/1989
# 10           1319  12/31/2006 0:00      1/3/1957        8/28/1989
# 11           1319  12/31/2007 0:00      1/3/1957        8/28/1989
# 12           1319  12/31/2008 0:00      1/3/1957        8/28/1989
# ...

# %% [markdown]
# #### 3.C [BONUS] Sort Data Frame using Age

# %%
# A:
df.sort_values('age', ascending = True)
# Out:
#        EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 48132        8325  12/31/2013 0:00     12/7/1994       11/29/2013
# 47925        8253  12/31/2013 0:00     5/15/1994        8/12/2013
# 47922        8252  12/31/2013 0:00     5/10/1994         8/9/2013
# 47919        8251  12/31/2013 0:00      5/7/1994         8/7/2013
# 47916        8250  12/31/2013 0:00     4/26/1994         8/2/2013
# 47913        8249  12/31/2013 0:00     4/23/1994        7/31/2013
# 47910        8248  12/31/2013 0:00     4/16/1994        7/27/2013
# 47492        8088  12/31/2012 0:00      1/1/1993       11/21/2012
# 47496        8089  12/31/2012 0:00      1/6/1993       11/23/2012
# 47907        8247  12/31/2013 0:00     4/14/1994        7/26/2013
# 47500        8090  12/31/2012 0:00      1/6/1993       11/23/2012
# 47504        8091  12/31/2012 0:00      1/6/1993       11/23/2012
# 47904        8246  12/31/2013 0:00      4/9/1994        7/24/2013
# ...

# %% [markdown]
# #### 3.D [BONUS] Using Sample Select Any Row

# %%
# A:

# %% [markdown]
# # 4. Query Data Frame
#
# #### 4.A Find Rows Where Job_Title is CEO

# %%
# A:
df.loc[df.job_title == 'CEO']
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
# 5        1318  12/31/2011 0:00      1/3/1954        8/28/1989
# 6        1318  12/31/2012 0:00      1/3/1954        8/28/1989
# 7        1318  12/31/2013 0:00      1/3/1954        8/28/1989
# 8        1318  12/31/2014 0:00      1/3/1954        8/28/1989
# 9        1318  12/31/2015 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# ...

# %% [markdown]
# #### 4.B Group By Age

# %%
# A:
df.groupby('age').groups
# Out:
# {19: Int64Index([47492, 47496, 47500, 47504, 47508, 47512, 47516, 47520, 47524,
#              47528,
#              ...
#              48153, 48156, 48159, 48162, 48165, 49636, 49645, 49646, 49649,
#              49651],
#             dtype='int64', length=158),
#  20: Int64Index([46484, 46489, 46494, 46499, 46504, 46509, 46514, 46519, 46524,
#              46529,
#              ...
#              48157, 48160, 48163, 48166, 49573, 49593, 49597, 49601, 49644,
#              49652],
#             dtype='int64', length=408),
#  21: Int64Index([45294, 45300, 45306, 45312, 45318, 45322, 45328, 45334, 45340,
#              45346,
#              ...
#              49637, 49638, 49639, 49640, 49641, 49642, 49643, 49647, 49648,
#              49650],
#             dtype='int64', length=703),
#  22: Int64Index([43779, 43786, 43788, 43789, 43796, 43803, 43805, 43812, 43814,
#              43821,
#              ...
#              49571, 49572, 49592, 49594, 49595, 49596, 49598, 49599, 49600,
# ...

# %% [markdown]
# # 5. Visualization
#
# > Indented block
#
#
#
# #### 5.A Plot Histogram of Age

# %%
# A:
df.hist(column='age')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x108b35550>]],
#       dtype=object)

# %% [markdown]
# #### 5.B BoxPlot of Age

# %%
# A:
boxplot = df.boxplot(column=['age'])

# %% [markdown]
# #### 5.C Scatterplot of age and length_of_service

# %%
# A:
df.plot.scatter(x = 'age', y = 'length_of_service', s=2,)

# %% [markdown]
# ## 5.D Plot Histogram of store_name

# %%
# A:
df.hist(column='store_name')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x119f94390>]],
#       dtype=object)

# %% [markdown]
# #### 5.E Print Statistical Summary of Age

# %%
# A:
df['age'].describe()
# Out:
# count    49653.000000
# mean        42.077035
# std         12.427257
# min         19.000000
# 25%         31.000000
# 50%         42.000000
# 75%         53.000000
# max         65.000000
# Name: age, dtype: float64

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2019 Institute of Data
#
#
# ---
#
#
#
# ---
